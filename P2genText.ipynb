# %%
# !pip3 install textgenrnn
# Out:
# Collecting textgenrnn
#   Using cached https://files.pythonhosted.org/packages/27/60/419daf7e2d87bcafc6f0f65736ce76e5cc83cebbae758dd59b4c1fae99cd/textgenrnn-2.0.0.tar.gz
# Collecting h5py (from textgenrnn)
#   Using cached https://files.pythonhosted.org/packages/60/06/cafdd44889200e5438b897388f3075b52a8ef01f28a17366d91de0fa2d05/h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scikit-learn (from textgenrnn)
#   Using cached https://files.pythonhosted.org/packages/d1/48/e9fa9e252abcd1447eff6f9257636af31758a6e46fd5ce5d3c879f6907cb/scikit_learn-0.22.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting tqdm (from textgenrnn)
#   Using cached https://files.pythonhosted.org/packages/cd/80/5bb262050dd2f30f8819626b7c92339708fe2ed7bd5554c8193b4487b367/tqdm-4.42.1-py2.py3-none-any.whl
# Collecting keras (from textgenrnn)
#   Using cached https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl
# Collecting tensorflow>=2.1.0 (from textgenrnn)
#   Could not find a version that satisfies the requirement tensorflow>=2.1.0 (from textgenrnn) (from versions: 0.12.1, 1.0.0, 1.0.1, 1.1.0rc0, 1.1.0rc1, 1.1.0rc2, 1.1.0, 1.2.0rc0, 1.2.0rc1, 1.2.0rc2, 1.2.0, 1.2.1, 1.3.0rc0, 1.3.0rc1, 1.3.0rc2, 1.3.0, 1.4.0rc0, 1.4.0rc1, 1.4.0, 1.4.1, 1.5.0rc0, 1.5.0rc1, 1.5.0, 1.5.1, 1.6.0rc0, 1.6.0rc1, 1.6.0, 1.7.0rc0, 1.7.0rc1, 1.7.0, 1.7.1, 1.8.0rc0, 1.8.0rc1, 1.8.0, 1.9.0rc0, 1.9.0rc1, 1.9.0rc2, 1.9.0, 1.10.0rc0, 1.10.0rc1, 1.10.0, 1.10.1, 1.11.0rc0, 1.11.0rc1, 1.11.0rc2, 1.11.0, 1.12.0rc0, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.12.2, 1.12.3, 1.13.0rc0, 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 2.0.0a0, 2.0.0b0, 2.0.0b1)
# No matching distribution found for tensorflow>=2.1.0 (from textgenrnn)

# %%
import tensorflow as tf
gpu_options = tf.GPUOptions(allow_growth=True)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
from textgenrnn import textgenrnn
textgen = textgenrnn()
# Out:
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/abicharanb/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
import pandas as pd

df_steam = pd.read_csv("./data/steam/witcher3.csv")

df_rev = df_steam['review']

# %%
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
textgen.train_on_texts(df_rev[:5000], num_epochs = 8, gen_epochs = 2)
# Out:
# Training on 2,021,056 character sequences.
# Epoch 1/8
# 15789/15789 [==============================] - 256s 16ms/step - loss: 0.8227
# Epoch 2/8
# 15789/15789 [==============================] - 257s 16ms/step - loss: 0.64710s - l
# ####################
# Temperature: 0.2
# ####################
# Definition for the game of the game, but it’s a lot moment and there are dearest to design to the end of the end of the best game in the bidd this game in the game, but it's a good outcome, but this game has the greatest relief in the game, but this has a lot of modifiers, so I don’t do in the game
#
# The best game of the game, it's the game is great, and you go to their boat expect, but that is just grain and a single playthrough of the city of the game and all the game is deedly to walk away for an adaptation to part in this game to be acks, and there are minor bugs. Some moments in the game,
#
# I played The Witcher game of the game, but in rpgs and in the game, from exploring and then the next thing you have the best game in the bight and bombs ( I gluke the character constant) as simply explainted the game in the game, but it's a loot as a tree since it good
#
# ####################
# Temperature: 0.5
# ####################
# It is ong on the main game files fucking into their time and additional lore they can abilities to the difficulty that do: a next level, so great one games, but that is just slughly hear, the characters. New of combat and stuff but at the same time here has much at you that it would before your cha
#
# I have no more to find a game that gives you to give it a decade and so on.You can't give it to start  neatle, and mutant of content. every character into the game in the game, this game is great, and you will still be exploited in the characters for the greatest world and how there are unique comp
#
# I long the other Witcher 3 is a very existive and since you don't like  are beat three i've played in a little just buy it, it is also great and they actually had a silver sword for the world game, which is so much better if you get the opportunion of the main story of all time.
#
# ####################
# Temperature: 1.0
# ####################
# I slide stray running the who buther am complex way some small this game.
#
# Definition and how much to that curability gets brancher to be a minus to some dectodless out there, better than that, please very importable system on the "locked melax intos, sidequest, these - so I enjoy that the game is distantly for such as you with a perfect experience.
#
# De looks of the game and there are beniuty on and loops. I completed even ingrave wole from qust at the world, earning each at every single stuffBoring ending on a city on an RPG would be.
#
# Epoch 3/8
# 15789/15789 [==============================] - 258s 16ms/step - loss: 0.4552
# Epoch 4/8
# 15789/15789 [==============================] - 256s 16ms/step - loss: 0.2999
# ####################
# Temperature: 0.2
# ####################
# This game is a solid 10/10 hours later on the city which was a decent equipment wise in one of yhry of my laster and game* Valley on my [b]One [url=http://steamcmment][/h1]
#
# I have noweved.
#
# This game is a solid 10/10 hours later or lost [/i] myself and game and make you love any character interactions that has nothing because I was too lazy armor that was disgusted by your play. You can have some where the game this game could be a combat each and you can end up with.Unfortund and som
#
# ####################
# Temperature: 0.5
# ####################
# This game keeps me from killing, only, and The Witcher have introduced an itself benefits fetch the very beliefs and better and beast, the story itself was quite one of my laster and playthrough was not allough the devil’TYo gets some of this year!
#
# Makes me hard
#
# There are a lot of different kinds of enemements feel. Literally better and load how progress they pretty good.The greatest points of it they deserve quest for explore, which is and in a keybod, can lead to well stuff to everyone, it is also included!
#
# ####################
# Temperature: 1.0
# ####################
# JUST PERTHIC DOWN
#
# great carn shin in one.
#
# What a game. It's a crosm with beautiful experiencs, which is antine (with defenging itself.) Vive friends hels-forga level and say how many cits some friends miscarrower.There is a fan the decadething books to the story into enjoyable where your horse is definitely really had a reason of contine e
#
# Epoch 5/8
# 15789/15789 [==============================] - 257s 16ms/step - loss: 0.1758
# Epoch 6/8
# 15789/15789 [==============================] - 255s 16ms/step - loss: 0.0908
# ####################
# Temperature: 0.2
# ####################
# The best game i have very etitant. I believe there are some mods during combat and sometimes does you the experience I download hours out with an open values. You can have some quests and stronger that I mean a LOT not explained but the direction of “[b]"Stop." [i] But fucking with the playiniis to
#
# This is probably the best game ive ever played
#
# This is probably the best game ive ever played
#
# ####################
# Temperature: 0.5
# ####################
# The best game in the whole game
#
# I gotta admit only the game where I west bad and with the game to add that they think it was releaded in this game and it could lesser them by areas what I mean a lot experience with some other old felt unique people was spectacularly written. New Geralt and the boss fights 10/10 different ones. Th
#
# This is probably the best game ive ever played
#
# ####################
# Temperature: 1.0
# ####################
# this game is an absolute masterpiece of arts mutant. Never finished another development, and voice acting them by around its finishing supporting of the game, the lastly story is real already for my face of the second playthrough . General amount of content water to get the previous experience Over
#
# Cannot recall how long I've had this game, but actual price, [trull then more in the blory of locksome! What an abseace. It is absolutely playable but its still looks much better than mmsers with various weapons and a spare complexike with all the characters and pretty quick with a lot of the decad
#
# Honestly this game has a special place of a sword for no major game, look until and buy this game is perfect!Imma build, which then ward. just give good her traiture, but horra worked in The Witcher 3 adds you can hard to many characters. [i] Best game i doesn't wored wrong from a contract witcher.
#
# Epoch 7/8
# 15789/15789 [==============================] - 256s 16ms/step - loss: 0.0421
# Epoch 8/8
# 15789/15789 [==============================] - 257s 16ms/step - loss: 0.0215
# ####################
# Temperature: 0.2
# ####################
# I have been playing PC games for three decades and this is easily one of the best two or three games I have ever played. Now with the reduced price, this game is literally a steal for anyone who hasn't already played it. Its graphics and design were so ahead of its time that it still looks much bet
#
# It's better than sex.
#
# This is probably the best game ive ever played
#
# ####################
# Temperature: 0.5
# ####################
# 13/10 best game i have ever played, good graphics, smooth gameplay, and the devs fixes bugs quickly not like cs :)
#
# It's so good.
#
# When a humble bardGraced a ride alongWith Geralt of Rivia, the 9. The repatervelous will say that this game feel a little including is on sale for bonished and finish collect at least interested and the main story is the best game in the main story is very good, although with the plethora of quests
#
# ####################
# Temperature: 1.0
# ####################
# An amazing fantasy RPG game. Well worth a multiple playhroughs.
#
# h
#
# Gameplay 10/10Graphics (for a 2015 game) 10/10Storytelling and quests 10/10Character dialogue, chest point of story, and so of there yea this cake are good.There is a must story or espoy. The world offers much to explore, with beautiful environments and plenty of loot and monster lairs to discover.
